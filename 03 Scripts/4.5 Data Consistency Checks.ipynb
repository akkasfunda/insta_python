# %% [markdown]
# ## 01 Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02 Import Data Sets

# %%
# Turn your project folder path into a string

# %%
path=r"C:\Users\sahin\Documents\Instacart Basket Analysis"

# %%
## Import the "orders.csv" data set from "Prepared Data" folder as df_ords

# %%
df_ords = pd.read_csv(os.path.join(path, "02 Data", "Prepared Data", "orders_wrangled.csv"), index_col = False)

# %%
## Import the "products.csv" data set from "Original data" folder as df_prods

# %%
df_prods = pd.read_csv(os.path.join(path, "02 Data", "Original Data", "products.csv"), index_col = False)

# %%
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_the_week  order_hour_of_day  days_since_prior_order
# count            3.421083e+06       3.421083e+06            3.214874e+06
# mean             2.776219e+00       1.345202e+01            1.111484e+01
# std              2.046829e+00       4.226088e+00            9.206737e+00
# min              0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %%
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %% [markdown]
# ## 03 Checking for Mixed-Type Data

# %%
# Create a dataframe

# %%
df_test = pd.DataFrame()

# %%
# Create a mixed type column

# %%
df_test['mix'] = ['a', 'b', 1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
# Checking for mixed-type of columns
for col in df_test.columns.tolist():
    weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_test[weird]) > 0:
        print (col)
# Out:
# mix

# %%
# Fix the mixed-type column
df_test['mix'] = df_test['mix'].astype('str')

# %% [markdown]
# ## 04 Missing Values

# %%
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
# Create a subset with the missing values
df_nan = df_prods[df_prods['product_name'].isnull() == True]
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
# Compare the number of rows in current dataframe with the number of rows in subset 
#  without missing values.

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
# Create a new dataframe with clean data

# %%
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
# Another way you can drop missing values is via the following command:
df_prods['product_name'].dropna(inplace = True)
# For leaving the original dataframe untouched we should use inplace = False

# %% [markdown]
# ## 05 Duplicates

# %%
# Look for full duplicates within your data frame

# %%
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
# Check the number of rows in the prods_clean dataframe
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
# Check the number of rows in the new dataframe doesn't include duplicates
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %% [markdown]
# #  Task 4.5

# %%
# Exercise 2
# Run the df.describe() function on your df_prods dataframe. Using your new knowledge about how to 
# interpret the output of this function, share in a markdown cell whether anything about the data 
# looks off or should be investigated further.
# Tip: Keep an eye on min and max values!

# %%
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %% [markdown]
# The maximum amount for the prices column is very high and needs to be investigated.

# %%
# Exercise 3. 
# Check for mixed-type data in your df_ords dataframe.

# %%
for col in df_test.columns.tolist():
    weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_test[weird]) > 0:
        print (col)

# %%
# Exercise 4.
# If you find mixed-type data, fix it. The column in question should contain observations of 
# a single data type.

# %% [markdown]
# There are no mixed-type columns in the df_ords dataframe.

# %%
# Exercise 5.

# %%
# Run a check for missing values in your df_ords dataframe.
# In a markdown cell, report your findings and propose an explanation for any missing values you find.

# %%
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# orders_day_of_the_week         0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
df_nan = df_ords[df_ords['days_since_prior_order'].isnull() == True]

# %%
df_nan
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 11               11   2168274        2    prior             1
# 26               26   1374495        3    prior             1
# 39               39   3343014        4    prior             1
# 45               45   2717275        5    prior             1
# ...             ...       ...      ...      ...           ...
# 3420930     3420930    969311   206205    prior             1
# 3420934     3420934   3189322   206206    prior             1
# 3421002     3421002   2166133   206207    prior             1
# 3421019     3421019   2227043   206208    prior             1
# 3421069     3421069   3154581   206209    prior             1
#
#          orders_day_of_the_week  order_hour_of_day  days_since_prior_order
# 0                             2                  8                     NaN
# ...

# %% [raw]
# There are 206209 missing values in the days_since_prior_order column. These missing values are pointing us that the first order of the new clients.

# %%
# Exercise 6.

# %%
# Address the missing values using an appropriate method.
# In a markdown cell, explain why you used your method of choice.

# %%
We cannot remove the missing values (third method) which have important information. Because they 
are the first orders of new customers. In the same way, imputing the value with the mean or median of 
the column is not a choice for here. Therefore, we need to create a new variable that acts like a flag 
based on the missing value. The new column should be called first_order and indicate whether it is the 
customers first order. The column then explains the missing values in the days_since_prior_order column.

# %%
# defining a new dataframe for cleaned data
df_ords_clean = df_ords

# %%
df_ords_clean['first_order'] = df_ords['days_since_prior_order'].isnull() == True

# %%
df_ords_clean.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0           0   2539329        1    prior             1
# 1           1   2398795        1    prior             2
# 2           2    473747        1    prior             3
# 3           3   2254736        1    prior             4
# 4           4    431534        1    prior             5
#
#    orders_day_of_the_week  order_hour_of_day  days_since_prior_order  \
# 0                       2                  8                     NaN
# 1                       3                  7                    15.0
# 2                       3                 12                    21.0
# 3                       4                  7                    29.0
# 4                       4                 15                    28.0
#
#    first_order
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False

# %%
df_ords_clean.tail(40)
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 3420416     3420416   3202089   206170    prior             1
# 3420423     3420423    896963   206171    prior             1
# 3420430     3420430   2526805   206172    prior             1
# 3420437     3420437   1717723   206173    prior             1
# 3420441     3420441    559098   206174    prior             1
# 3420494     3420494   1946643   206175    prior             1
# 3420501     3420501   2939252   206176    prior             1
# 3420516     3420516   2441067   206177    prior             1
# 3420524     3420524   2962368   206178    prior             1
# 3420544     3420544   1777474   206179    prior             1
# 3420548     3420548    566068   206180    prior             1
# 3420567     3420567    351920   206181    prior             1
# 3420582     3420582    485448   206182    prior             1
# 3420593     3420593     31169   206183    prior             1
# ...

# %%
# Exercise 7.

# %%
# Run a check for duplicate values in your df_ords data.
# In a markdown cell, report your findings and propose an explanation for any duplicate values 
# you find.

# %%
df_ords_dups = df_ords_clean[df_ords_clean.duplicated()]
df_ords_dups
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, eval_set, order_number, orders_day_of_the_week, order_hour_of_day, days_since_prior_order]
# Index: []

# %%
Empty dataframe 
Columns: [ Unnamed;0, order_id, user_id, eval_set, order_number, orders_days_of _the_week, 
          order_hour_of_day, days_since_prior_order, first_order]

# %%
# Exercise 8

# %%
# Address the duplicates using an appropriate method.
# In a markdown cell, explain why you used your method of choice.

# %%
df_ords_dups.shape
# Out:
# (0, 8)

# %%
There are no duplicate values.

# %%
# Exercise 9

# %%
# Export your final, cleaned df_prods and df_ords data as “.csv” files in your “Prepared Data” folder 
# and give them appropriate, succinct names.

# %%
df_prods_clean_no_dups.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_cleaned.csv'))

# %%
df_ords_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_cleaned_csv'))
