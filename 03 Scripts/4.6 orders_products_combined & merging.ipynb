# %%
# Import Libraries

import pandas as pd
import numpy as np
import os

# %%
# Turn your project folder path into a string

# %%
path=r"C:\Users\sahin\Documents\Instacart Basket Analysis"

# %%
# Import the data set into as df_ords_prior

# %%
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_products__prior.csv'), index_col = False)

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)

# %%
# Check the output
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
# Check the output
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0           0   2539329        1    prior             1
# 1           1   2398795        1    prior             2
# 2           2    473747        1    prior             3
# 3           3   2254736        1    prior             4
# 4           4    431534        1    prior             5
#
#    orders_day_of_the_week  order_hour_of_day  days_since_prior_order
# 0                       2                  8                     NaN
# 1                       3                  7                    15.0
# 2                       3                 12                    21.0
# 3                       4                  7                    29.0
# 4                       4                 15                    28.0

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.shape
# Out:
# (3421083, 8)

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0           0   2539329        1    prior             1
# 1           0   2539329        1    prior             1
# 2           0   2539329        1    prior             1
# 3           0   2539329        1    prior             1
# 4           0   2539329        1    prior             1
#
#    orders_day_of_the_week  order_hour_of_day  days_since_prior_order  \
# 0                       2                  8                     NaN
# 1                       2                  8                     NaN
# 2                       2                  8                     NaN
# 3                       2                  8                     NaN
# 4                       2                  8                     NaN
#
#    product_id  add_to_cart_order  reordered _merge
# 0         196                  1          0   both
# 1       14084                  2          0   both
# 2       12427                  3          0   both
# 3       26088                  4          0   both
# 4       26405                  5          0   both

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', how = 'outer', indicator = True)

# %%
df_merged_large.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0           0   2539329        1    prior             1
# 1           0   2539329        1    prior             1
# 2           0   2539329        1    prior             1
# 3           0   2539329        1    prior             1
# 4           0   2539329        1    prior             1
#
#    orders_day_of_the_week  order_hour_of_day  days_since_prior_order  \
# 0                       2                  8                     NaN
# 1                       2                  8                     NaN
# 2                       2                  8                     NaN
# 3                       2                  8                     NaN
# 4                       2                  8                     NaN
#
#    product_id  add_to_cart_order  reordered _merge
# 0       196.0                1.0        0.0   both
# 1     14084.0                2.0        0.0   both
# 2     12427.0                3.0        0.0   both
# 3     26088.0                4.0        0.0   both
# 4     26405.0                5.0        0.0   both

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only       206209
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merged_large
# Out:
#           Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                  0   2539329        1    prior             1
# 1                  0   2539329        1    prior             1
# 2                  0   2539329        1    prior             1
# 3                  0   2539329        1    prior             1
# 4                  0   2539329        1    prior             1
# ...              ...       ...      ...      ...           ...
# 32640693     3421081   2977660   206209    prior            13
# 32640694     3421081   2977660   206209    prior            13
# 32640695     3421081   2977660   206209    prior            13
# 32640696     3421081   2977660   206209    prior            13
# 32640697     3421082    272231   206209    train            14
#
#           orders_day_of_the_week  order_hour_of_day  days_since_prior_order  \
# 0                              2                  8                     NaN
# 1                              2                  8                     NaN
# 2                              2                  8                     NaN
# 3                              2                  8                     NaN
# 4                              2                  8                     NaN
# ...                          ...                ...                     ...
# 32640693                       1                 12                     7.0
# 32640694                       1                 12                     7.0
# 32640695                       1                 12                     7.0
# 32640696                       1                 12                     7.0
# 32640697                       6                 14                    30.0
#
#           product_id  add_to_cart_order  reordered     _merge
# 0              196.0                1.0        0.0       both
# 1            14084.0                2.0        0.0       both
# 2            12427.0                3.0        0.0       both
# 3            26088.0                4.0        0.0       both
# 4            26405.0                5.0        0.0       both
# ...              ...                ...        ...        ...
# 32640693     38730.0                6.0        0.0       both
# 32640694     31477.0                7.0        0.0       both
# 32640695      6567.0                8.0        0.0       both
# 32640696     22920.0                9.0        0.0       both
# 32640697         NaN                NaN        NaN  left_only
#
# [32640698 rows x 12 columns]

# %%
# Export data to pickle

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Export data to csv

# %%
df_merged_large.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.csv'))
