# %% [markdown]
# ## Improt Libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
path=r"C:\Users\sahin\Documents\Instacart Basket Analysis"

# %%
## Import the data set into ords_prods_merged dataframe

# %%
ords_prods_merged = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.csv'), index_col = False)

# %%
# Create a subset

# %%
df = ords_prods_merged[ : 1000000]

# %%
df.shape
# Out:
# (1000000, 16)

# %%
# Define price_label function and apply it to subset

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low range product'      
  elif (row['prices'] > 5) and (row['prices'] <=15) :
    return 'Mid range product'
  elif row['prices'] > 15 :
    return 'High range product'      
  else: return np.nan

# %%
# Apply the function

# %%
df['price_range'] = df.apply(price_label, axis = 1)
# Out:
# C:\Users\sahin\AppData\Local\Temp/ipykernel_5932/935325922.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis = 1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid range product     668114
# Low range product     312168
# High range product     12340
# NaN                     7378
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %% [markdown]
# If-Statement with the loc() Function

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\sahin\anaconda3\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\sahin\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <=5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     668114
# Low-range product     312168
# High-range product     12340
# NaN                     7378
# Name: price_range_loc, dtype: int64

# %% [markdown]
# Repeating the process again this time, on your entire dataframe as opposed to the subset

# %%
ords_prods_merged.loc[ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merged.loc[(ords_prods_merged['prices'] <= 15) & (ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merged.loc[ords_prods_merged['prices'] <= 5, 'price_range product'] = 'Low-range product'

# %%
ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# NaN                   10362730
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# If-Statements with For-Loops

# %%
ords_prods_merged['orders_day_of_the_week'].value_counts(dropna = False)
# Out:
# 0    6252941
# 1    5696724
# 6    4530304
# 2    4243173
# 5    4236989
# 3    3868747
# 4    3812390
# Name: orders_day_of_the_week, dtype: int64

# %%
result = []

for value in ords_prods_merged["orders_day_of_the_week"]:
    if value == 0:
        result.append("Busiest day")
    elif value == 4:
        result.append("Least busy")
    else:
        result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %% [markdown]
# ** Output exceeds the size limit. Open the full output data in a text editor

# %%
ords_prods_merged['busiest_day'] = result

# %%
ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22575937
# Busiest day        6252941
# Least busy         3812390
# Name: busiest_day, dtype: int64

# %% [markdown]
# Questions and answers

# %% [markdown]
# ##1. If you haven’t done so already, complete the instructions in the Exercise for creating the “price_label” and “busiest_day” columns.
# * its has been done in the above

# %% [markdown]
# 2. Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
ords_prods_merged['orders_day_of_the_week'].value_counts(dropna = False)
# Out:
# 0    6252941
# 1    5696724
# 6    4530304
# 2    4243173
# 5    4236989
# 3    3868747
# 4    3812390
# Name: orders_day_of_the_week, dtype: int64

# %%
result = []

for value in ords_prods_merged["orders_day_of_the_week"]:
    if value == 0 and 1:
        result.append("Two Busiest Days")
    elif value == 3 and 4:
        result.append("Two Slowest Days")
    else:
        result.append("regularly Busy")

# %%
result
# Out:
# ['regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'Two Slowest Days',
#  'Two Slowest Days',
#  'Two Slowest Days',
#  'Two Slowest Days',
#  'Two Slowest Days',
#  'Two Slowest Days',
#  'Two Slowest Days',
#  'Two Slowest Days',
#  'Two Slowest Days',
#  'Two Slowest Days',
#  'Two Slowest Days',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
#  'regularly Busy',
# ...

# %%
ords_prods_merged['Busiest_days'] = result

# %%
ords_prods_merged['Busiest_days'].value_counts(dropna = False)
# Out:
# regularly Busy      22519580
# Two Busiest Days     6252941
# Two Slowest Days     3868747
# Name: Busiest_days, dtype: int64

# %% [markdown]
#  3. Check the values of this new column for accuracy. Note any observations in markdown format

# %%
ords_prods_merged.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0           0   2539329        1    prior             1
# 1           1   2539329        1    prior             1
# 2           2   2539329        1    prior             1
# 3           3   2539329        1    prior             1
# 4           4   2539329        1    prior             1
#
#    orders_day_of_the_week  order_hour_of_day  days_since_prior_order  \
# 0                       2                  8                     NaN
# 1                       2                  8                     NaN
# 2                       2                  8                     NaN
# 3                       2                  8                     NaN
# 4                       2                  8                     NaN
#
#    product_id  add_to_cart_order  reordered  \
# 0       196.0                1.0        0.0
# 1     14084.0                2.0        0.0
# 2     12427.0                3.0        0.0
# ...

# %% [markdown]
#  4. When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2781009
# 11    2755369
# 14    2709084
# 15    2682090
# 13    2680171
# 12    2637533
# 16    2554110
# 9     2471067
# 17    2104225
# 8     1729871
# 18    1649870
# 19    1268365
# 20     983232
# 7      897163
# 21     801052
# 22     638671
# 23     405051
# 6      292533
# 0      220337
# 1      116589
# 5       88661
# 2       69904
# 4       53636
# 3       51675
# Name: order_hour_of_day, dtype: int64

# %%
result = []

for value in ords_prods_merged["order_hour_of_day"]:
    if value in [10, 11, 14, 15, 13, 12, 16, 9]: # value == 10 or value == 11 or ...
        result.append("most_orders")
    elif value in [3, 4, 2, 5, 1, 0, 6, 23]:
        result.append("fewest_orders")
    else:
        result.append("average_orders")

# %%
result[0:15]
# Out:
# ['average_orders',
#  'average_orders',
#  'average_orders',
#  'average_orders',
#  'average_orders',
#  'average_orders',
#  'average_orders',
#  'average_orders',
#  'average_orders',
#  'average_orders',
#  'average_orders',
#  'most_orders',
#  'most_orders',
#  'most_orders',
#  'most_orders']

# %%
ords_prods_merged['busiest_period_of_day'] = result

# %% [markdown]
# 5. Print the frequency for this new column.

# %%
ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# most_orders       21270433
# average_orders    10072449
# fewest_orders      1298386
# Name: busiest_period_of_day, dtype: int64

# %%
ords_prods_merged.sample(50)
# Out:
#           Unnamed: 0  order_id  user_id eval_set  order_number  \
# 29161834    29161834   2262145   184053    prior             2
# 18172235    18172235    594425   114236    prior            14
# 15343274    15343274   1564482    96434    prior            17
# 2779505      2779505   2258332    17679    prior            17
# 5716783      5716783   1785074    36154    prior            10
# 29617850    29617850   3399789   186935    prior             7
# 21645981    21645981   2307539   136632    prior            11
# 9633060      9633060    538469    60734    prior            39
# 1199563      1199563   2123958     7714    prior             8
# 2513753      2513753   2614454    16042    prior             2
# 16102089    16102089    776456   101189    prior            11
# 13312273    13312273   1193186    83726    prior             4
# 5311092      5311092   3025697    33533    prior             8
# 26769424    26769424   2781562   169119    prior             9
# ...

# %% [markdown]
# 7. Export your dataframe as a pickle file (since you added new columns) and store it correctly in your “Prepared Data” folder.

# %%
ords_prods_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', '4.7_orders_products_merge_deriving_new.pkl'))

# %%
ords_prods_merged.to_csv(os.path.join(path, '02 Data', 'Prepared Data', '4.7_orders_products_merge_deriving_new.csv'))
